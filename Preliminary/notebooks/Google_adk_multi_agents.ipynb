# %% [markdown]
# # Lesson 3 - Introduction to Google's ADK - Part II

# %% [markdown]
# In this lesson, you will familiarize yourself with Google's Agent Development Kit (ADK) that you will use in the next lessons to build your multi-agent system.
#
# You'll learn:
# - how to create and run an agent using ADK (Part I)
# - how to create a team of Agents consisting of a root agent and 2 sub-agents (Part II)
# - how the team of agents can access a sharable context (Part II)
#
# For each agent, you'll define a tool that allows the agent to interact with the Neo4j database we setup for this course.

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>To access the helper.py and neo4j_for_adk.py files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
# </div>

# %% [markdown]
# ## 3.1. Setup

# %%
# !pip install "google-adk[extensions]"
# Out:
# Requirement already satisfied: google-adk[extensions] in /usr/local/lib/python3.12/dist-packages (1.25.1)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.12.1)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.6.8)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (8.3.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.133.0)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.190.0)
# Requirement already satisfied: google-auth>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (2.47.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.132.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.138.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.36.2)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (3.40.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.35.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.35.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.26.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (3.63.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.36.1)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (3.9.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.64.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.21)
# Requirement already satisfied: httpx<1.0.0,>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.26.0)
# Requirement already satisfied: opentelemetry-api<1.40.0,>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.40.0,>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.12.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.32.4)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.17.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (2.0.47)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.41.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (15.0.1)
# Requirement already satisfied: anthropic>=0.43.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.84.0)
# Requirement already satisfied: beautifulsoup4>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (4.13.5)
# Requirement already satisfied: docker>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (7.1.0)
# Requirement already satisfied: kubernetes>=29.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (35.0.0)
# Requirement already satisfied: langgraph<0.4.8,>=0.2.60 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.4.7)
# Requirement already satisfied: litellm<1.80.17,>=1.75.5 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (1.80.16)
# Requirement already satisfied: llama-index-readers-file>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.5.6)
# Requirement already satisfied: llama-index-embeddings-google-genai>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.3.2)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (6.0.2)
# Requirement already satisfied: pypika>=0.50.0 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.51.1)
# Requirement already satisfied: toolbox-adk<0.6.0,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from google-adk[extensions]) (0.5.8)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.43.0->google-adk[extensions]) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.43.0->google-adk[extensions]) (0.17.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.43.0->google-adk[extensions]) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.43.0->google-adk[extensions]) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk[extensions]) (3.11)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2.0.0,>=1.6.6->google-adk[extensions]) (43.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=3.2.2->google-adk[extensions]) (2.8.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker>=7.0.0->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0.0,>=0.124.1->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0.0,>=0.124.1->google-adk[extensions]) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (4.9.1)
# Requirement already satisfied: pyopenssl>=20.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (24.2.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.27.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (5.29.6)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.16.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.18.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (3.13.0)
# Requirement already satisfied: google-cloud-iam in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (2.21.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery>=2.2.0->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery>=2.2.0->google-adk[extensions]) (2.8.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery-storage>=2.0.0->google-adk[extensions]) (1.78.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk[extensions]) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub<3.0.0,>=2.0.0->google-adk[extensions]) (1.71.2)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (2.29.1)
# Requirement already satisfied: mmh3>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (5.2.0)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (3.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.27.0->google-adk[extensions]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.27.0->google-adk[extensions]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.0->google-adk[extensions]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29.0.0->google-adk[extensions]) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29.0.0->google-adk[extensions]) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29.0.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=29.0.0->google-adk[extensions]) (0.10)
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.2.15)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.0.8)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.6.0)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm<1.80.17,>=1.75.5->google-adk[extensions]) (0.14.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm<1.80.17,>=1.75.5->google-adk[extensions]) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm<1.80.17,>=1.75.5->google-adk[extensions]) (3.1.6)
# Requirement already satisfied: openai>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm<1.80.17,>=1.75.5->google-adk[extensions]) (2.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm<1.80.17,>=1.75.5->google-adk[extensions]) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm<1.80.17,>=1.75.5->google-adk[extensions]) (0.22.2)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.14.15)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (0.7.1)
# Requirement already satisfied: pandas<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (2.2.2)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (6.7.4)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (0.0.26)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->google-adk[extensions]) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (3.2.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk[extensions]) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk[extensions]) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk[extensions]) (1.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk[extensions]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk[extensions]) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk[extensions]) (3.4.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0->google-adk[extensions]) (3.3.2)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from sqlalchemy-spanner>=1.14.0->google-adk[extensions]) (1.18.4)
# Requirement already satisfied: toolbox-core==0.5.8 in /usr/local/lib/python3.12/dist-packages (from toolbox-adk<0.6.0,>=0.5.7->google-adk[extensions]) (0.5.8)
# Requirement already satisfied: google-auth-oauthlib<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from toolbox-adk<0.6.0,>=0.5.7->google-adk[extensions]) (1.2.4)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.15 in /usr/local/lib/python3.12/dist-packages (from toolbox-core==0.5.8->toolbox-adk<0.6.0,>=0.5.7->google-adk[extensions]) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (1.22.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (0.4.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (3.3.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (3.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.7.6)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.14.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint>=2.0.26->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk>=0.1.42->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.11.7)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.4.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.6.7)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2025.3.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.15.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (3.6.1)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (4.9.2)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (82.0.0)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.2.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (4.67.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file>=0.4.0->google-adk[extensions]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file>=0.4.0->google-adk[extensions]) (2025.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=29.0.0->google-adk[extensions]) (3.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (2025.11.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk[extensions]) (1.3.10)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (1.4.1)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.6.6->google-adk[extensions]) (3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (3.24.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (1.3.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (0.24.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.25.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (3.26.2)
# Requirement already satisfied: griffecli==2.0.0 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: griffelib==2.0.0 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffecli==2.0.0->griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.4.6)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (0.24.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<1.80.17,>=1.75.5->google-adk[extensions]) (0.1.2)

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /usr/local/lib/python3.12/dist-packages (6.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from neo4j) (2025.2)

# %%
import os

# Put your Sandbox details here
os.environ["NEO4J_URI"] = "bolt://44.203.44.233"
os.environ["NEO4J_USERNAME"] = "neo4j"
os.environ["NEO4J_PASSWORD"] = "types-holder-amusement"

# %%
from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm # For OpenAI support
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.genai import types # For creating message Content/Parts
from typing import Optional, Dict, Any

# Convenience libraries for working with Neo4j inside of Google ADK
from neo4j_for_adk import graphdb

import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.CRITICAL)

print("Libraries imported.")
# Out:
# Libraries imported.

# %%
import os
from google.adk.models.google_llm import Gemini

# 1. Lock in your credentials securely
os.environ["GEMINI_API_KEY"] = "***"

llm = Gemini(model="gemini-2.5-flash")

# %% [markdown]
# ## 3.2. Set up AgentCaller

# %% [markdown]
# Remember that we defined `AgentCaller` in part I as a simple wrapper for interacting with an ADK agent. Additionally we defined a factory function `make_agent_caller` to make instances of `AgentCaller`. Let's import the factory function from the `helper` script.

# %%
from helper import make_agent_caller

# %% [markdown]
# ## 3.3. A Simple Multi-Agent Team \- Delegation for Greetings & Farewells

# %% [markdown]
# Using multiple agents is a common pattern in real-world applications. It allows for better modularity, specialization, and scalability.
#
# **You will:**
#
# 1. Define another simple tool that will handle farewells (`say_goodbye`).
# 2. Create two new specialized sub-agents: `greeting_agent` and `farewell_agent`.
# 3. Create a new top-level agent (`cypher_agent_team`) to act as the **root agent**.
# 4. Configure the root agent with its sub-agents, enabling **automatic delegation**.
# 5. Test the delegation flow by sending different types of requests to the root agent.

# %% [markdown]
# ### 3.3.1 Define Tools for Sub-Agents

# %%
# Define the hello tool
def say_hello(person_name: str) -> dict:
    """Formats a welcome message to a named person.

    Args:
        person_name (str): the name of the person saying hello

    Returns:
        dict: A dictionary containing the results of the query.
              Includes a 'status' key ('success' or 'error').
              If 'success', includes a 'query_result' key with an array of result rows.
              If 'error', includes an 'error_message' key.
    """
    return graphdb.send_query("RETURN 'Hello to you, ' + $person_name AS reply",
    {
        "person_name": person_name
    })

# %%
# Define the new goodbye tool
def say_goodbye() -> dict:
    """Provides a simple farewell message to conclude the conversation."""
    return graphdb.send_query("RETURN 'Goodbye from Cypher!' as farewell")

# %% [markdown]
# ### 3.3.2. Define the Sub-Agents (Greeting & Farewell)

# %% [markdown]
# Now, create the `Agent` instances for our specialists. Notice their highly focused `instruction` and, critically, their clear `description`. The `description` is the primary information the *root agent* uses to decide *when* to delegate to these sub-agents.
#
# **Best Practice:**
# - Sub-agent `description` fields should accurately and concisely summarize their specific capability. This is crucial for effective automatic delegation.
# - Sub-agent `instruction` fields should be tailored to their limited scope, telling them exactly what to do and *what not* to do (e.g., "Your *only* task is...").

# %%
# --- Greeting Agent ---
greeting_subagent = Agent(
    model=llm,
    name="greeting_subagent_v1",
    instruction="You are the Greeting Agent. Your ONLY task is to provide a friendly greeting to the user. "
                "Use the 'say_hello' tool to generate the greeting. "
                "If the user provides their name, make sure to pass it to the tool. "
                "Do not engage in any other conversation or tasks.",
    description="Handles simple greetings and hellos using the 'say_hello' tool.", # Crucial for delegation
    tools=[say_hello],
)
print(f"✅ Agent '{greeting_subagent.name}' created.")
# Out:
# ✅ Agent 'greeting_subagent_v1' created.

# %%
# --- Farewell Agent ---
farewell_subagent = Agent(
    # Can use the same or a different model
    model=llm, # Sticking with GPT for this example
    name="farewell_subagent_v1",
    instruction="You are the Farewell Agent. Your ONLY task is to provide a polite goodbye message. "
                "Use the 'say_goodbye' tool when the user indicates they are leaving or ending the conversation "
                "(e.g., using words like 'bye', 'goodbye', 'thanks bye', 'see you'). "
                "Do not perform any other actions.",
    description="Handles simple farewells and goodbyes using the 'say_goodbye' tool.", # Crucial for delegation
    tools=[say_goodbye],
)
print(f"✅ Agent '{farewell_subagent.name}' created.")
# Out:
# ✅ Agent 'farewell_subagent_v1' created.

# %% [markdown]
# ### 3.3.3. Define the Root Agent with Sub-Agents

# %% [markdown]
# The `root_agent` can now manage sub-agents by including them in the `sub_agents` parameter and updating its instructions to explain when to delegate tasks. With this setup, ADK enables automatic delegation: if a user query is better suited to a sub-agent based on its description, the root agent will automatically hand off control to that sub-agent. For effective delegation, clearly specify in the root agent’s instructions which sub-agents exist and when to delegate to them.

# %%
root_agent = Agent(
    name="friendly_agent_team_v1", # Give it a new version name
    model=llm,
    description="The main coordinator agent. Delegates greetings/farewells to specialists.",
    instruction="""You are the main Agent coordinating a team. Your primary responsibility is to be friendly.

                You have specialized sub-agents:
                1. 'greeting_agent': Handles simple greetings like 'Hi', 'Hello'. Delegate to it for these.
                2. 'farewell_agent': Handles simple farewells like 'Bye', 'See you'. Delegate to it for these.

                Analyze the user's query. If it's a greeting, delegate to 'greeting_agent'.
                If it's a farewell, delegate to 'farewell_agent'.

                For anything else, respond appropriately or state you cannot handle it.
                """,
    tools=[], # No tools for the root agent
    # Key change: Link the sub-agents here!
    sub_agents=[greeting_subagent, farewell_subagent]
)


print(f"✅ Root Agent '{root_agent.name}' created with sub-agents: {[sa.name for sa in root_agent.sub_agents]}")
# Out:
# ✅ Root Agent 'friendly_agent_team_v1' created with sub-agents: ['greeting_subagent_v1', 'farewell_subagent_v1']

# %% [markdown]
# ### 3.3.4. Interact with the Agent Team

# %% [markdown]
# Now that you've defined our root agent with its specialized sub-agents, let's test the delegation mechanism.

# %%
from helper import make_agent_caller

root_agent_caller = await make_agent_caller(root_agent)

async def run_team_conversation():
    await root_agent_caller.call("Hello I'm ABK", True)

    await root_agent_caller.call("Thanks, bye!", True)

# Execute the conversation using await
await run_team_conversation()
# Out:
# >>> User Query: Hello I'm ABK
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-3095/540523962.py in <cell line: 1>()
#       9
#      10 # Execute the conversation using await
# ---> 11 await run_team_conversation()
#
# /tmp/ipython-input-3095/540523962.py in run_team_conversation()
#       4
#       5 async def run_team_conversation():
# ----> 6     await root_agent_caller.call("Hello I'm ABK", True)
#       7
#       8     await root_agent_caller.call("Thanks, bye!", True)
#
# /content/helper.py in call(self, query, verbose)
#      53         # Key Concept: run_async executes the agent logic and yields Events.
#      54         # We iterate through events to find the final answer.
# ---> 55         async for event in self.runner.run_async(user_id=self.user_id, session_id=self.session_id, new_message=content):
#      56             # You can uncomment the line below to see *all* events during execution
#      57             if verbose:
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     559
#     560     async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 561       async for event in agen:
#     562         yield event
#     563
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in _run_with_trace(new_message, invocation_id)
#     547             )
#     548         ) as agen:
# --> 549           async for event in agen:
#     550             yield event
#     551         # Run compaction after all events are yielded from the agent.
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in _exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     776
#     777       async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 778         async for event in agen:
#     779           _apply_run_config_custom_metadata(
#     780               event, invocation_context.run_config
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in execute(ctx)
#     536         async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     537           async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 538             async for event in agen:
#     539               yield event
#     540
#
# /usr/local/lib/python3.12/dist-packages/google/adk/agents/base_agent.py in run_async(self, parent_context)
#     292
#     293       async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294         async for event in agen:
#     295           yield event
#     296
#
# /usr/local/lib/python3.12/dist-packages/google/adk/agents/llm_agent.py in _run_async_impl(self, ctx)
#     466     should_pause = False
#     467     async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 468       async for event in agen:
#     469         self.__maybe_save_output_to_state(event)
#     470         yield event
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in run_async(self, invocation_context)
#     425       last_event = None
#     426       async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 427         async for event in agen:
#     428           last_event = event
#     429           yield event
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_one_step_async(self, invocation_context)
#     502         )
#     503     ) as agen:
# --> 504       async for llm_response in agen:
#     505         # Postprocess after calling the LLM.
#     506         async with Aclosing(
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_async(self, invocation_context, llm_request, model_response_event)
#     964
#     965     async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 966       async for event in agen:
#     967         yield event
#     968
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_with_tracing()
#     947               )
#     948           ) as agen:
# --> 949             async for llm_response in agen:
#     950               trace_call_llm(
#     951                   invocation_context,
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1182         yield error_response
#    1183       else:
# -> 1184         raise model_error
#    1185
#    1186   def __get_llm(self, invocation_context: InvocationContext) -> BaseLlm:
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1167             llm_request, invocation_context, model_response_event
#    1168         ) as span:
# -> 1169           async for llm_response in agen:
#    1170             tracing.trace_generate_content_result(span, llm_response)
#    1171             yield llm_response
#
# /usr/local/lib/python3.12/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     264         raise _ResourceExhaustedError(ce) from ce
#     265
# --> 266       raise ce
#     267
#     268   async def _generate_content_via_interactions(
#
# /usr/local/lib/python3.12/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     243
#     244       else:
# --> 245         response = await self.api_client.aio.models.generate_content(
#     246             model=llm_request.model,
#     247             contents=llm_request.contents,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    7473             indices_str,
#    7474         )
# -> 7475       return await self._generate_content(
#    7476           model=model, contents=contents, config=parsed_config
#    7477       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    6240     request_dict = _common.encode_unserializable_types(request_dict)
#    6241
# -> 6242     response = await self._api_client.async_request(
#    6243         'post', path, request_dict, http_options
#    6244     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in async_request(self, http_method, path, request_dict, http_options)
#    1440     )
#    1441
# -> 1442     result = await self._async_request(
#    1443         http_request=http_request, http_options=http_options, stream=False
#    1444     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _async_request(self, http_request, http_options, stream)
#    1373         retry = tenacity.AsyncRetrying(**retry_kwargs)
#    1374         return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1375     return await self._async_retry(  # type: ignore[no-any-return]
#    1376         self._async_request_once, http_request, stream
#    1377     )
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     110         is_async = _utils.is_coroutine_callable(fn)
#     111         while True:
# --> 112             do = await self.iter(retry_state=retry_state)
#     113             if isinstance(do, DoAttempt):
#     114                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     155         result = None
#     156         for action in self.iter_state.actions:
# --> 157             result = await action(retry_state)
#     158         return result
#     159
#
# /usr/local/lib/python3.12/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#     109
#     110     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111         return call(*args, **kwargs)
#     112
#     113     return inner
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     411                 retry_exc = self.retry_error_cls(fut)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#     415
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     182     def reraise(self) -> t.NoReturn:
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#     186
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     114                 try:
#     115                     if is_async:
# --> 116                         result = await fn(*args, **kwargs)
#     117                     else:
#     118                         result = fn(*args, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _async_request_once(self, http_request, stream)
#    1318               **self._async_client_session_request_args,
#    1319           )
# -> 1320           await errors.APIError.raise_for_async_response(response)
#    1321           return HttpResponse(response.headers, [await response.text()])
#    1322         except (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_async_response(cls, response)
#     214         raise ValueError(f'Unsupported response type: {type(response)}')
#     215
# --> 216     await cls.raise_error_async(status_code, response_json, response)
#     217
#     218   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error_async(cls, status_code, response_json, response)
#     236     """
#     237     if 400 <= status_code < 500:
# --> 238       raise ClientError(status_code, response_json, response)
#     239     elif 500 <= status_code < 600:
#     240       raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key expired. Please renew the API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key expired. Please renew the API key.'}]}}

# %% [markdown]
# You've now structured your application with multiple collaborating agents. This modular design is fundamental for building more complex and capable agent systems. In the next step, you'll give our agents the ability to remember information across turns using session state.

# %% [markdown]
# ## 3.4. Adding Memory and Personalization with Session State

# %% [markdown]
# **Optional Reading**
#
# Currently, agents can delegate tasks but cannot remember past interactions. To enable memory for context-aware behavior, ADK uses **Session State**—a Python dictionary linked to each user session.
#
# > `session.state` is tied to a specific user session identified by `APP_NAME`, `USER_ID`, `SESSION_ID`. It persists information *across multiple conversational turns* within that session.
#
# Session State lets agents and tools store and retrieve information across multiple turns. Tools access this state through the ToolContext object, while agents can automatically save their final responses using the output_key setting.
#
# 1. **`ToolContext`** Tools can accept a `ToolContext` object giving access to the session state via `tool_context.state` allowing tools to save information *during* execution.
# 2. **`output_key`**  Agents can have `output_key="your_key"` allowing ADK to save the agent's final textual response into `session.state["your_key"]`.
#
# These constructs allow agents to remember past details, adapt their actions, and personalize responses during a session.

# %% [markdown]
# ### 3.4.1. Create State-Aware hello/goodbye Tools

# %% [markdown]
# You will create a new version of the hello/goodbye tools. The key feature is accepting `tool_context: ToolContext`
# which allows them to access `tool_context.state`.
#
# They will write to or read from the `user_name` state variable.
#
#
# * **Key Concept: `ToolContext`** This object is the bridge allowing your tool logic to interact with the session's context, including reading and writing state variables. ADK injects it automatically if defined as the last parameter of your tool function.
#
#
# * **Best Practice:** When reading from state, use `dictionary.get('key', default_value)` to handle cases where the key might not exist yet, ensuring your tool doesn't crash.

# %%
from google.adk.tools.tool_context import ToolContext

def say_hello_stateful(user_name:str, tool_context:ToolContext):
    """Says hello to the user, recording their name into state.

    Args:
        user_name (str): The name of the user.
    """
    tool_context.state["user_name"] = user_name
    print("\ntool_context.state['user_name']:", tool_context.state["user_name"])
    return graphdb.send_query(
        f"RETURN 'Hello to you, ' + $user_name + '.' AS reply",
    {
        "user_name": user_name
    })

# %%
def say_goodbye_stateful(tool_context: ToolContext) -> dict:
    """Says goodbye to the user, reading their name from state."""
    user_name = tool_context.state.get("user_name", "stranger")
    print("\ntool_context.state['user_name']:", user_name)
    return graphdb.send_query("RETURN 'Goodbye, ' + $user_name + ', nice to chat with you!' AS reply",
    {
        "user_name": user_name
    })


print("✅ State-aware 'say_hello_stateful' and 'say_goodbye_stateful' tools defined.")
# Out:
# ✅ State-aware 'say_hello_stateful' and 'say_goodbye_stateful' tools defined.

# %% [markdown]
# ### 3.4.2. Redefine Sub-Agents and Update Root Agent

# %% [markdown]
# To ensure this step is self-contained and builds correctly, you first redefine the `greeting_agent` and `farewell_agent` exactly as they were in Step 3.3\. Then, you define the new root agent (`root_agent_stateful`):
#
# * It uses the new `say_hello_stateful` and `say_goodbye_stateful` tools.
# * It includes the greeting and farewell sub-agents for delegation.

# %%
# define a stateful greeting agent. the only difference is that this agent will use the stateful say_hello_stateful tool
greeting_agent_stateful = Agent(
    model=llm,
    name="greeting_agent_stateful_v1",
    instruction="You are the Greeting Agent. Your ONLY task is to provide a friendly greeting using the 'say_hello' tool. Do nothing else.",
    description="Handles simple greetings and hellos using the 'say_hello_stateful' tool.",
    tools=[say_hello_stateful],
)
print(f"✅ Agent '{greeting_agent_stateful.name}' redefined.")
# Out:
# ✅ Agent 'greeting_agent_stateful_v1' redefined.

# %%
farewell_agent_stateful = Agent(
    model=llm,
    name="farewell_agent_stateful_v1",
    instruction="You are the Farewell Agent. Your ONLY task is to provide a polite goodbye message using the 'say_goodbye_stateful' tool. Do not perform any other actions.",
    description="Handles simple farewells and goodbyes using the 'say_goodbye_stateful' tool.",
    tools=[say_goodbye_stateful],
)
print(f"✅ Agent '{farewell_agent_stateful.name}' redefined.")
# Out:
# ✅ Agent 'farewell_agent_stateful_v1' redefined.

# %%
root_agent_stateful = Agent(
    name="friendly_team_stateful", # New version name
    model=llm,
    description="The main coordinator agent. Delegates greetings/farewells to specialists.",
    instruction="""You are the main Agent coordinating a team. Your primary responsibility is to be friendly.

                You have specialized sub-agents:
                1. 'greeting_agent_stateful': Handles simple greetings like 'Hi', 'Hello'. Delegate to it for these.
                2. 'farewell_agent_stateful': Handles simple farewells like 'Bye', 'See you'. Delegate to it for these.

                Analyze the user's query. If it's a greeting, delegate to 'greeting_agent_stateful'. If it's a farewell, delegate to 'farewell_agent_stateful'.

                For anything else, respond appropriately or state you cannot handle it.
                """,
        tools=[], # Still no tools for root
        sub_agents=[greeting_agent_stateful, farewell_agent_stateful], # Include sub-agents
    )

print(f"✅ Root Agent '{root_agent_stateful.name}' created using agents with stateful tools.")
# Out:
# ✅ Root Agent 'friendly_team_stateful' created using agents with stateful tools.

# %% [markdown]
# ### 3.4.3. Interact and Test State Flow

# %% [markdown]
# Now, you can initialize a new `AgentCaller`. This time, you'll provide an initial state.
#
# Then you can execute a conversation designed to test the state interactions using the `root_agent_stateful` root agent.

# %%
root_stateful_caller = await make_agent_caller(root_agent_stateful)

session = await root_stateful_caller.get_session()

print(f"Initial State: {session.state}")
# Out:
# Initial State: {}

# %% [markdown]
# Now, you can define a conversation, run it, then examine the final session state.

# %%
import asyncio

async def run_stateful_conversation():
    print("Sending first message...")
    await root_stateful_caller.call("Hello, I'm ABK!")

    # Pause for 15 seconds to respect the free tier rate limit
    print("Waiting for rate limit reset...")
    await asyncio.sleep(15)

    print("Sending second message...")
    await root_stateful_caller.call("Thanks, bye!")

# Execute the conversation
await run_stateful_conversation()

session = await root_stateful_caller.get_session()
print(f"\nFinal State: {session.state}")
# Out:
# Sending first message...
#
# >>> User Query: Hello, I'm ABK!
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     244       else:
# --> 245         response = await self.api_client.aio.models.generate_content(
#     246             model=llm_request.model,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    7474         )
# -> 7475       return await self._generate_content(
#    7476           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    6241
# -> 6242     response = await self._api_client.async_request(
#    6243         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in async_request(self, http_method, path, request_dict, http_options)
#    1441
# -> 1442     result = await self._async_request(
#    1443         http_request=http_request, http_options=http_options, stream=False
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _async_request(self, http_request, http_options, stream)
#    1374         return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1375     return await self._async_retry(  # type: ignore[no-any-return]
#    1376         self._async_request_once, http_request, stream
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     111         while True:
# --> 112             do = await self.iter(retry_state=retry_state)
#     113             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     156         for action in self.iter_state.actions:
# --> 157             result = await action(retry_state)
#     158         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#     110     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111         return call(*args, **kwargs)
#     112
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     115                     if is_async:
# --> 116                         result = await fn(*args, **kwargs)
#     117                     else:
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _async_request_once(self, http_request, stream)
#    1319           )
# -> 1320           await errors.APIError.raise_for_async_response(response)
#    1321           return HttpResponse(response.headers, [await response.text()])
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_async_response(cls, response)
#     215
# --> 216     await cls.raise_error_async(status_code, response_json, response)
#     217
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error_async(cls, status_code, response_json, response)
#     237     if 400 <= status_code < 500:
# --> 238       raise ClientError(status_code, response_json, response)
#     239     elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 31.248683641s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '31s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# /tmp/ipython-input-3095/183361880.py in <cell line: 1>()
#      13
#      14 # Execute the conversation
# ---> 15 await run_stateful_conversation()
#      16
#      17 session = await root_stateful_caller.get_session()
#
# /tmp/ipython-input-3095/183361880.py in run_stateful_conversation()
#       3 async def run_stateful_conversation():
#       4     print("Sending first message...")
# ----> 5     await root_stateful_caller.call("Hello, I'm ABK!")
#       6
#       7     # Pause for 15 seconds to respect the free tier rate limit
#
# /content/helper.py in call(self, query, verbose)
#      53         # Key Concept: run_async executes the agent logic and yields Events.
#      54         # We iterate through events to find the final answer.
# ---> 55         async for event in self.runner.run_async(user_id=self.user_id, session_id=self.session_id, new_message=content):
#      56             # You can uncomment the line below to see *all* events during execution
#      57             if verbose:
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     559
#     560     async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 561       async for event in agen:
#     562         yield event
#     563
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in _run_with_trace(new_message, invocation_id)
#     547             )
#     548         ) as agen:
# --> 549           async for event in agen:
#     550             yield event
#     551         # Run compaction after all events are yielded from the agent.
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in _exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     776
#     777       async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 778         async for event in agen:
#     779           _apply_run_config_custom_metadata(
#     780               event, invocation_context.run_config
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in execute(ctx)
#     536         async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     537           async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 538             async for event in agen:
#     539               yield event
#     540
#
# /usr/local/lib/python3.12/dist-packages/google/adk/agents/base_agent.py in run_async(self, parent_context)
#     292
#     293       async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294         async for event in agen:
#     295           yield event
#     296
#
# /usr/local/lib/python3.12/dist-packages/google/adk/agents/llm_agent.py in _run_async_impl(self, ctx)
#     466     should_pause = False
#     467     async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 468       async for event in agen:
#     469         self.__maybe_save_output_to_state(event)
#     470         yield event
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in run_async(self, invocation_context)
#     425       last_event = None
#     426       async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 427         async for event in agen:
#     428           last_event = event
#     429           yield event
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_one_step_async(self, invocation_context)
#     502         )
#     503     ) as agen:
# --> 504       async for llm_response in agen:
#     505         # Postprocess after calling the LLM.
#     506         async with Aclosing(
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_async(self, invocation_context, llm_request, model_response_event)
#     964
#     965     async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 966       async for event in agen:
#     967         yield event
#     968
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_with_tracing()
#     947               )
#     948           ) as agen:
# --> 949             async for llm_response in agen:
#     950               trace_call_llm(
#     951                   invocation_context,
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1182         yield error_response
#    1183       else:
# -> 1184         raise model_error
#    1185
#    1186   def __get_llm(self, invocation_context: InvocationContext) -> BaseLlm:
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1167             llm_request, invocation_context, model_response_event
#    1168         ) as span:
# -> 1169           async for llm_response in agen:
#    1170             tracing.trace_generate_content_result(span, llm_response)
#    1171             yield llm_response
#
# /usr/local/lib/python3.12/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     262         # client error that developers would run into. We enhance the messaging
#     263         # with possible fixes to this issue.
# --> 264         raise _ResourceExhaustedError(ce) from ce
#     265
#     266       raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 31.248683641s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '31s'}]}}

# %% [markdown]
# ## 3.5. Finally, An Interactive Conversation

# %% [markdown]
# Now, let's make this interactive so you can ask your own questions! Run the cell below. It will prompt you to enter your queries directly.
#
# **Note:** In the video, we re-run the first cell in 3.4.3 to start with a fresh state (no stored name). You might get different results from the video.

# %%
async def run_interactive_conversation():
    while True:
        user_query = input("Ask me something (or type 'exit' to quit): ")
        if user_query.lower() == 'exit':
            break
        response = await root_stateful_caller.call(user_query)
        print(f"Response: {response}")

# Execute the interactive conversation
await run_interactive_conversation()
# Out:
# Ask me something (or type 'exit' to quit): hello
#
# >>> User Query: hello
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     244       else:
# --> 245         response = await self.api_client.aio.models.generate_content(
#     246             model=llm_request.model,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    7474         )
# -> 7475       return await self._generate_content(
#    7476           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    6241
# -> 6242     response = await self._api_client.async_request(
#    6243         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in async_request(self, http_method, path, request_dict, http_options)
#    1441
# -> 1442     result = await self._async_request(
#    1443         http_request=http_request, http_options=http_options, stream=False
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _async_request(self, http_request, http_options, stream)
#    1374         return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1375     return await self._async_retry(  # type: ignore[no-any-return]
#    1376         self._async_request_once, http_request, stream
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     111         while True:
# --> 112             do = await self.iter(retry_state=retry_state)
#     113             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     156         for action in self.iter_state.actions:
# --> 157             result = await action(retry_state)
#     158         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#     110     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111         return call(*args, **kwargs)
#     112
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     115                     if is_async:
# --> 116                         result = await fn(*args, **kwargs)
#     117                     else:
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _async_request_once(self, http_request, stream)
#    1319           )
# -> 1320           await errors.APIError.raise_for_async_response(response)
#    1321           return HttpResponse(response.headers, [await response.text()])
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_async_response(cls, response)
#     215
# --> 216     await cls.raise_error_async(status_code, response_json, response)
#     217
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error_async(cls, status_code, response_json, response)
#     237     if 400 <= status_code < 500:
# --> 238       raise ClientError(status_code, response_json, response)
#     239     elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 24.300242816s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# /tmp/ipython-input-3095/2203738447.py in <cell line: 1>()
#       8
#       9 # Execute the interactive conversation
# ---> 10 await run_interactive_conversation()
#
# /tmp/ipython-input-3095/2203738447.py in run_interactive_conversation()
#       4         if user_query.lower() == 'exit':
#       5             break
# ----> 6         response = await root_stateful_caller.call(user_query)
#       7         print(f"Response: {response}")
#       8
#
# /content/helper.py in call(self, query, verbose)
#      53         # Key Concept: run_async executes the agent logic and yields Events.
#      54         # We iterate through events to find the final answer.
# ---> 55         async for event in self.runner.run_async(user_id=self.user_id, session_id=self.session_id, new_message=content):
#      56             # You can uncomment the line below to see *all* events during execution
#      57             if verbose:
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     559
#     560     async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 561       async for event in agen:
#     562         yield event
#     563
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in _run_with_trace(new_message, invocation_id)
#     547             )
#     548         ) as agen:
# --> 549           async for event in agen:
#     550             yield event
#     551         # Run compaction after all events are yielded from the agent.
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in _exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     776
#     777       async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 778         async for event in agen:
#     779           _apply_run_config_custom_metadata(
#     780               event, invocation_context.run_config
#
# /usr/local/lib/python3.12/dist-packages/google/adk/runners.py in execute(ctx)
#     536         async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     537           async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 538             async for event in agen:
#     539               yield event
#     540
#
# /usr/local/lib/python3.12/dist-packages/google/adk/agents/base_agent.py in run_async(self, parent_context)
#     292
#     293       async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294         async for event in agen:
#     295           yield event
#     296
#
# /usr/local/lib/python3.12/dist-packages/google/adk/agents/llm_agent.py in _run_async_impl(self, ctx)
#     466     should_pause = False
#     467     async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 468       async for event in agen:
#     469         self.__maybe_save_output_to_state(event)
#     470         yield event
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in run_async(self, invocation_context)
#     425       last_event = None
#     426       async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 427         async for event in agen:
#     428           last_event = event
#     429           yield event
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_one_step_async(self, invocation_context)
#     502         )
#     503     ) as agen:
# --> 504       async for llm_response in agen:
#     505         # Postprocess after calling the LLM.
#     506         async with Aclosing(
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_async(self, invocation_context, llm_request, model_response_event)
#     964
#     965     async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 966       async for event in agen:
#     967         yield event
#     968
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_with_tracing()
#     947               )
#     948           ) as agen:
# --> 949             async for llm_response in agen:
#     950               trace_call_llm(
#     951                   invocation_context,
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1182         yield error_response
#    1183       else:
# -> 1184         raise model_error
#    1185
#    1186   def __get_llm(self, invocation_context: InvocationContext) -> BaseLlm:
#
# /usr/local/lib/python3.12/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1167             llm_request, invocation_context, model_response_event
#    1168         ) as span:
# -> 1169           async for llm_response in agen:
#    1170             tracing.trace_generate_content_result(span, llm_response)
#    1171             yield llm_response
#
# /usr/local/lib/python3.12/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     262         # client error that developers would run into. We enhance the messaging
#     263         # with possible fixes to this issue.
# --> 264         raise _ResourceExhaustedError(ce) from ce
#     265
#     266       raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 24.300242816s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}
